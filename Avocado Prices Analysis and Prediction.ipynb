# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Load the dataset

# %%
avocado=pd.read_csv("avocado.csv")
avocado.tail(10)
# Out:
#        Unnamed: 0 Date  AveragePrice  Total Volume  4046  4225  4770  \
# 16458         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16459         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16460         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16461         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16462         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16463         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16464         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16465         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16466         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16467         NaN  NaN           NaN           NaN   NaN   NaN   NaN
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags type  year region
# 16458         NaN         NaN         NaN          NaN  NaN   NaN    NaN
# ...

# %%
avocado.head(10)
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0         0.0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1         1.0  20-12-2015          1.35      54876.98   674.28   44638.81
# 2         2.0  13-12-2015          0.93     118220.22   794.70  109149.67
# 3         3.0  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4         4.0  29-11-2015          1.28      51039.60   941.48   43838.39
# 5         5.0  22-11-2015          1.26      55979.78  1184.27   48067.99
# 6         6.0  15-11-2015          0.99      83453.76  1368.92   73672.72
# 7         7.0  08-11-2015          0.98     109428.33   703.75  101815.36
# 8         8.0  01-11-2015          1.02      99811.42  1022.15   87315.57
# 9         9.0  25-10-2015          1.07      74338.76   842.40   64757.44
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# ...

# %% [markdown]
# # EDA Process

# %%
avocado.dropna(axis=0, how='all', thresh=None, subset=None, inplace=True)

# %% [markdown]
# Here, I have deleted the rows where missing values are present in all the columns by using how="all".

# %%
avocado.tail(10)
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume      4046      4225  \
# 1507         5.0  20-11-2016          1.57     135608.11  44044.69  28907.47
# 1508         6.0  13-11-2016          1.64     144089.12  49399.39  26597.39
# 1509         7.0  06-11-2016          1.57     142095.92  36840.74  27501.34
# 1510         8.0  30-10-2016          1.58     142955.49  39376.44  29382.30
# 1511         9.0  23-10-2016          1.52     167741.27  54981.90  39749.81
# 1512        10.0  16-10-2016          1.39     190846.01  57529.11  56366.66
# 1513        11.0  09-10-2016          1.51     178235.75  43325.87  52189.61
# 1514        12.0  02-10-2016          1.48     178410.82  46364.75  52893.38
# 1515        13.0  25-09-2016          1.47     189131.52  54110.79  53593.58
# 1516        14.0  18-09-2016          1.43     182978.30  43116.41  54193.42
#
#           4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# ...

# %% [markdown]
# I have checked the last 10 columns. Now, there are no rows present in the dataset where missing values are present in all the columns.

# %%
avocado.rename(columns={'Unnamed: 0':'ID'},inplace=True)

# %% [markdown]
# Here, I have changed the unnamed column name to ID by using rename method.

# %%
avocado.head()
# Out:
#     ID        Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  0.0  27-12-2015          1.33      64236.62  1036.74   54454.85   48.16
# 1  1.0  20-12-2015          1.35      54876.98   674.28   44638.81   58.33
# 2  2.0  13-12-2015          0.93     118220.22   794.70  109149.67  130.50
# 3  3.0  06-12-2015          1.08      78992.15  1132.00   71976.41   72.58
# 4  4.0  29-11-2015          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type    year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015.0
# 1     9505.56     9408.07       97.49          0.0  conventional  2015.0
# 2     8145.35     8042.21      103.14          0.0  conventional  2015.0
# 3     5811.16     5677.40      133.76          0.0  conventional  2015.0
# 4     6183.95     5986.26      197.69          0.0  conventional  2015.0
#
#    region
# 0  Albany
# 1  Albany
# 2  Albany
# 3  Albany
# 4  Albany

# %% [markdown]
# The unnamed column has been changed successfully

# %%
avocado.columns
# Out:
# Index(['ID', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
avocado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1517 entries, 0 to 1516
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            1517 non-null   float64
#  1   Date          1517 non-null   object
#  2   AveragePrice  1517 non-null   float64
#  3   Total Volume  1517 non-null   float64
#  4   4046          1517 non-null   float64
#  5   4225          1517 non-null   float64
#  6   4770          1517 non-null   float64
#  7   Total Bags    1517 non-null   float64
#  8   Small Bags    1517 non-null   float64
#  9   Large Bags    1517 non-null   float64
#  10  XLarge Bags   1517 non-null   float64
#  11  type          1517 non-null   object
#  12  year          1517 non-null   float64
#  13  region        1517 non-null   object
# dtypes: float64(11), object(3)
# memory usage: 177.8+ KB

# %% [markdown]
# By using info we can observe the following results :
#
#     1. There are no null values present in any column.
#
#     2."Date" and "type" columns are object type. The other columns are float type which means numeric.We need to change the object type variable to numeric. So Date and type column type should be changed.

# %% [markdown]
# Xplit the year,month and day in different columns

# %%
avocado['Date']=pd.to_datetime(avocado['Date'])
avocado['Date']
avocado["Year"]=avocado['Date'].dt.year
avocado["Month"]=avocado['Date'].dt.month
avocado["Day"]=avocado['Date'].dt.day

# %% [markdown]
# To split the year,month and day in different columns I have change the datatype of Date column to datetime64

# %%
avocado.columns
# Out:
# Index(['ID', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region', 'Year', 'Month', 'Day'],
#       dtype='object')

# %%
avocado.head(10)
# Out:
#     ID       Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  0.0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  1.0 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2.0 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  3.0 2015-06-12          1.08      78992.15  1132.00   71976.41   72.58
# 4  4.0 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# 5  5.0 2015-11-22          1.26      55979.78  1184.27   48067.99   43.61
# 6  6.0 2015-11-15          0.99      83453.76  1368.92   73672.72   93.26
# 7  7.0 2015-08-11          0.98     109428.33   703.75  101815.36   80.00
# 8  8.0 2015-01-11          1.02      99811.42  1022.15   87315.57   85.34
# 9  9.0 2015-10-25          1.07      74338.76   842.40   64757.44  113.00
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type    year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015.0
# ...

# %%
avocado.shape
# Out:
# (1517, 17)

# %% [markdown]
# There are 1517 rows and 17 columns

# %%
avocado.nunique()
# Out:
# ID                52
# Date             104
# AveragePrice     113
# Total Volume    1517
# 4046            1517
# 4225            1517
# 4770            1516
# Total Bags      1517
# Small Bags      1517
# Large Bags      1377
# XLarge Bags      711
# type               1
# year               2
# region            51
# Year               2
# Month             12
# Day               31
# dtype: int64

# %% [markdown]
# Here, we can get the following observations :
#
#     1. All the values in "Total Volume","4046","4225","Total Bags" these 4 columns are unique.So, these columns may not have very good correlation with the target variable.
#
#     2. The are two same columns named 'year' and 'Year'. Let me delete 'Year' column from the dataset.
#
#     3. In the 'type' column there is only one unique value. It may not effect too much to thge dataset.
#
#     4.'4770' columns has 1516 unique values which is huge. So,this column may not effect the target variable as well.
#
#     5.The other columns have unique values.But not all the values. Some values are same. So these columns will effect the final prediction.
#     6.I have splited the Date column. So, let me delete this column as well.

# %%
avocado.isnull().sum()
# Out:
# ID              0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# Year            0
# Month           0
# Day             0
# dtype: int64

# %% [markdown]
# There are no null values present in any columns

# %%
avocado.drop(['Year','Date'], axis=1,inplace=True)

# %%
avocado.columns
# Out:
# Index(['ID', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region', 'Month', 'Day'],
#       dtype='object')

# %% [markdown]
# The 'Year' column has been deleted

# %%
avocado.describe()
# Out:
#                 ID  AveragePrice  Total Volume          4046          4225  \
# count  1517.000000   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03
# mean     26.995386      1.074990  1.601879e+06  6.464387e+05  6.114375e+05
# std      14.848287      0.188891  4.433143e+06  1.947614e+06  1.672906e+06
# min       0.000000      0.490000  3.875074e+04  4.677200e+02  1.783770e+03
# 25%      14.000000      0.980000  1.474700e+05  2.040034e+04  4.147606e+04
# 50%      29.000000      1.080000  4.027919e+05  8.175117e+04  1.186649e+05
# 75%      39.000000      1.190000  9.819751e+05  3.775785e+05  4.851503e+05
# max      51.000000      1.680000  4.465546e+07  1.893304e+07  1.895648e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000
# mean   5.040550e+04  2.935974e+05  2.487736e+05  4.264205e+04    2181.771074
# ...

# %% [markdown]
# Results :
#
#     75 percentile and max value
#
#     1. In the 'Total Volume' 75 percentile and max value has huge diffenece. Most probably there are outliers.
#
#     2. In the "4046","4225","4770","Total Bags","Small Bags","Large Bags","XLarge Bags" colums  75 percentile and max value has huge diffenece. Most probably there are outliers. So, there are outliers too.
#
#     3. In the "ID", "AveragePrice", "year", "Month", "Day" columns 75 percentile and max value has no huge diffenece. It looks normal.
#
#     50 percentile(median) and mean value
#
#     1. In the 'Total Volume',"4046","4225","4770","Total Bags","Small Bags","Large Bags","XLarge Bags" 50 percentile and mean value has huge diffenece. Most probably there are outliers.
#
#     2.In the "ID", "AveragePrice", "year", "Month", "Day" columns 50 percentile and mean value has no huge diffenece. It looks normal.

# %% [markdown]
# # Correlation:

# %%
avocado.corr()
# Out:
#                     ID  AveragePrice  Total Volume      4046      4225  \
# ID            1.000000     -0.075531      0.091934  0.092013  0.093566
# AveragePrice -0.075531      1.000000     -0.140470 -0.190096 -0.092084
# Total Volume  0.091934     -0.140470      1.000000  0.985568  0.987154
# 4046          0.092013     -0.190096      0.985568  1.000000  0.951952
# 4225          0.093566     -0.092084      0.987154  0.951952  1.000000
# 4770          0.075647     -0.100567      0.934347  0.898570  0.927757
# Total Bags    0.081007     -0.111597      0.967689  0.930395  0.951779
# Small Bags    0.083485     -0.097682      0.960642  0.922278  0.943988
# Large Bags    0.065364     -0.177480      0.910226  0.884229  0.900496
# XLarge Bags  -0.050993     -0.048284      0.521717  0.474063  0.504718
# year         -0.012854      0.178683     -0.004189 -0.040439 -0.007254
# Month        -0.598729      0.060642     -0.055212 -0.053007 -0.058429
# ...

# %% [markdown]
# Observation result :
#
#     Negative correlation with Average price : 'ID','Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags'
#
#     Positive correlation : 'year','Month', 'Day'
#
#     Strong correlation :  'Total Volume', '4046', 'Large Bags', 'year'
#
#     Weak correlation:   'ID','4225', '4770','Total Bags', 'Small Bags','XLarge Bags' ,'Month', 'Day'

# %%
plt.subplots(figsize=(25,15))
sns.heatmap(avocado.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can also get the same result using avocado.corr() method.

# %% [markdown]
# # Check outliers

# %%
avocado.plot(kind='box',subplots=True,layout=(2,8),color='green',figsize=(13,6))
plt.tight_layout()

# %% [markdown]
# Some columns are not important. Such as 'Total Bags', 'Small Bags','XLarge Bags','Large Bags' will not effect over the average price of the dataset. So, let me delete these columns.

# %%
avocado.columns
# Out:
# Index(['ID', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region', 'Month', 'Day'],
#       dtype='object')

# %%
avocado.drop(['Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags'],axis=1,inplace=True)

# %% [markdown]
# All the values in "Total Volume","4046","4225" these 4 columns are unique.'4770' columns has 1516 unique values. Even there are a lot of outliers. So, those columns will also be deleted.

# %%
avocado.head()
# Out:
#     ID  AveragePrice  Total Volume     4046       4225    4770          type  \
# 0  0.0          1.33      64236.62  1036.74   54454.85   48.16  conventional
# 1  1.0          1.35      54876.98   674.28   44638.81   58.33  conventional
# 2  2.0          0.93     118220.22   794.70  109149.67  130.50  conventional
# 3  3.0          1.08      78992.15  1132.00   71976.41   72.58  conventional
# 4  4.0          1.28      51039.60   941.48   43838.39   75.78  conventional
#
#      year  region  Month  Day
# 0  2015.0  Albany     12   27
# 1  2015.0  Albany     12   20
# 2  2015.0  Albany     12   13
# 3  2015.0  Albany      6   12
# 4  2015.0  Albany     11   29

# %%
sns.pairplot(avocado)

# %% [markdown]
# two clusters are present in most of the plots.

# %%
sns.pairplot(avocado,hue='type')

# %% [markdown]
# 'type' column has only one value called conventional. That's why it looks same as before

# %%
avocado.shape
# Out:
# (1517, 11)

# %% [markdown]
# There is only one kind conventional.

# %%
avocado.columns
# Out:
# Index(['ID', 'AveragePrice', 'Total Volume', '4046', '4225', '4770', 'type',
#        'year', 'region', 'Month', 'Day'],
#       dtype='object')

# %%
label_cols=['type','region']
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
avocado[label_cols]=avocado[label_cols].apply(lambda x:label.fit_transform(x))

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
scale_cols=avocado.drop(['AveragePrice','type','region'],axis=1)
col_trans=make_column_transformer((OneHotEncoder(),avocado[label_cols].columns),(StandardScaler(),scale_cols.columns),remainder='passthrough')

# %%
avocado.head()
# Out:
#     ID  AveragePrice  Total Volume     4046       4225    4770  type    year  \
# 0  0.0          1.33      64236.62  1036.74   54454.85   48.16     0  2015.0
# 1  1.0          1.35      54876.98   674.28   44638.81   58.33     0  2015.0
# 2  2.0          0.93     118220.22   794.70  109149.67  130.50     0  2015.0
# 3  3.0          1.08      78992.15  1132.00   71976.41   72.58     0  2015.0
# 4  4.0          1.28      51039.60   941.48   43838.39   75.78     0  2015.0
#
#    region  Month  Day
# 0       0     12   27
# 1       0     12   20
# 2       0     12   13
# 3       0      6   12
# 4       0     11   29

# %%
avocado.describe()
# Out:
#                 ID  AveragePrice  Total Volume          4046          4225  \
# count  1517.000000   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03
# mean     26.995386      1.074990  1.601879e+06  6.464387e+05  6.114375e+05
# std      14.848287      0.188891  4.433143e+06  1.947614e+06  1.672906e+06
# min       0.000000      0.490000  3.875074e+04  4.677200e+02  1.783770e+03
# 25%      14.000000      0.980000  1.474700e+05  2.040034e+04  4.147606e+04
# 50%      29.000000      1.080000  4.027919e+05  8.175117e+04  1.186649e+05
# 75%      39.000000      1.190000  9.819751e+05  3.775785e+05  4.851503e+05
# max      51.000000      1.680000  4.465546e+07  1.893304e+07  1.895648e+07
#
#                4770    type         year       region        Month  \
# count  1.517000e+03  1517.0  1517.000000  1517.000000  1517.000000
# mean   5.040550e+04     0.0  2015.162821    21.196440     6.362558
# std    1.377812e+05     0.0     0.369324    16.132398     3.472146
# ...

# %% [markdown]
# Here we can see that in "Total Volume","4046","4225","4770" these columns min value and max value has huge difference. So, let me use standard scaling technique.

# %%
avocado
# Out:
#         ID  AveragePrice  Total Volume      4046       4225      4770  type  \
# 0      0.0          1.33      64236.62   1036.74   54454.85     48.16     0
# 1      1.0          1.35      54876.98    674.28   44638.81     58.33     0
# 2      2.0          0.93     118220.22    794.70  109149.67    130.50     0
# 3      3.0          1.08      78992.15   1132.00   71976.41     72.58     0
# 4      4.0          1.28      51039.60    941.48   43838.39     75.78     0
# ...    ...           ...           ...       ...        ...       ...   ...
# 1512  10.0          1.39     190846.01  57529.11   56366.66  17531.78     0
# 1513  11.0          1.51     178235.75  43325.87   52189.61  19419.57     0
# 1514  12.0          1.48     178410.82  46364.75   52893.38  16736.92     0
# 1515  13.0          1.47     189131.52  54110.79   53593.58  17495.42     0
# 1516  14.0          1.43     182978.30  43116.41   54193.42  16563.91     0
#
#         year  region  Month  Day
# ...

# %% [markdown]
# # Label Encoding

# %% [markdown]
# Some columns such as 'region' and 'type' has object type value. I have changed it to numeric by using LabelEncoding method.

# %%
avocado.head()
# Out:
#     ID  AveragePrice  Total Volume     4046       4225    4770  type    year  \
# 0  0.0          1.33      64236.62  1036.74   54454.85   48.16     0  2015.0
# 1  1.0          1.35      54876.98   674.28   44638.81   58.33     0  2015.0
# 2  2.0          0.93     118220.22   794.70  109149.67  130.50     0  2015.0
# 3  3.0          1.08      78992.15  1132.00   71976.41   72.58     0  2015.0
# 4  4.0          1.28      51039.60   941.48   43838.39   75.78     0  2015.0
#
#    region  Month  Day
# 0       0     12   27
# 1       0     12   20
# 2       0     12   13
# 3       0      6   12
# 4       0     11   29

# %%
avocado.columns
# Out:
# Index(['ID', 'AveragePrice', 'Total Volume', '4046', '4225', '4770', 'type',
#        'year', 'region', 'Month', 'Day'],
#       dtype='object')

# %% [markdown]
# # Checking skewness

# %%
import itertools
cols=['ID', 'AveragePrice', 'type', 'region', 'Month', 'Day', 'year_2015.0',
       'year_2016.0']
length=len(cols)
cs=["b","r","g","c","m","k","lime"]
fig=plt.figure(figsize=(22,18))

for i,j,k in itertools.zip_longest(cols,range(length),cs):
    plt.subplot(3,5,j+1)
    ax=sns.distplot(avocado[i],color=k,rug=True)
    ax.set_facecolor("w")
    plt.axvline(avocado[i].mean(),linestyle="dashed",label="mean",color="k")
    plt.legend(loc="best")
    plt.title(i,color="navy")
    plt.xlabel("")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2055: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# Skewness is present in almost all the columns

# %%
avocado.dtypes

# %% [markdown]
# Now every column has been changed to numeric

# %%
avocado.plot(kind='box',subplots=True,layout=(2,8),color='green',figsize=(13,6))
plt.tight_layout()

# %% [markdown]
# # Remove Outliers

# %% [markdown]
# # z-score

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(avocado))
threshold=3
new_avocado=avocado[(z<3).all(axis=1)]
print(avocado.shape)
print(new_avocado.shape)
# Out:
# (1517, 11)
# (0, 11)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:2500: RuntimeWarning: invalid value encountered in true_divide
#   return (a - mns) / sstd

# %% [markdown]
# New avocado has 0 row now. So z score will not be accepted.

# %% [markdown]
# # IQR

# %%
q1=avocado.quantile(0.25)
q3=avocado.quantile(0.75)
IQR=q3-q1
print(IQR)
# Out:
# ID                  25.00
# AveragePrice         0.21
# Total Volume    834505.09
# 4046            357178.14
# 4225            443674.28
# 4770             28256.05
# type                 0.00
# year                 0.00
# region              29.00
# Month                6.00
# Day                 15.00
# dtype: float64

# %%
avocado_new1=avocado[~((avocado<(q1-1.5*IQR))|(avocado>(q3+1.5*IQR))).any(axis=1)]
print(avocado_new1.shape)
# Out:
# (990, 11)

# %% [markdown]
# # Percentage Loss

# %%
percentage_loss=(527/1517)*100
print(percentage_loss)
# Out:
# 34.73961766644694

# %% [markdown]
# Percentage Loss is more than 18%.It's huge loose of Data. So,let me go to the next step with outliers

# %% [markdown]
# # Split the data into training and testing set

# %%
x=avocado.drop('AveragePrice',axis=1)
y=avocado['AveragePrice']

# %% [markdown]
# # Removing skewness

# %%
from sklearn.preprocessing import power_transform     #box-cox is only for positive but yeo-johnson is for both negative and positive
x=power_transform(x,method='yeo-johnson')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2995: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())

# %% [markdown]
# Here, I have used yeo-johnson method.Because it works for both positive and negative.

# %%
avocado.columns
# Out:
# Index(['ID', 'AveragePrice', 'Total Volume', '4046', '4225', '4770', 'type',
#        'year', 'region', 'Month', 'Day'],
#       dtype='object')

# %% [markdown]
# # Using Histogram for visualization

# %%
avocado.hist(edgecolor="red",linewidth=1.5,figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'ID'}>,
#         <AxesSubplot:title={'center':'AveragePrice'}>,
#         <AxesSubplot:title={'center':'Total Volume'}>],
#        [<AxesSubplot:title={'center':'4046'}>,
#         <AxesSubplot:title={'center':'4225'}>,
#         <AxesSubplot:title={'center':'4770'}>],
#        [<AxesSubplot:title={'center':'type'}>,
#         <AxesSubplot:title={'center':'year'}>,
#         <AxesSubplot:title={'center':'region'}>],
#        [<AxesSubplot:title={'center':'Month'}>,
#         <AxesSubplot:title={'center':'Day'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
avocado
# Out:
#         ID  AveragePrice  Total Volume      4046       4225      4770  type  \
# 0      0.0          1.33      64236.62   1036.74   54454.85     48.16     0
# 1      1.0          1.35      54876.98    674.28   44638.81     58.33     0
# 2      2.0          0.93     118220.22    794.70  109149.67    130.50     0
# 3      3.0          1.08      78992.15   1132.00   71976.41     72.58     0
# 4      4.0          1.28      51039.60    941.48   43838.39     75.78     0
# ...    ...           ...           ...       ...        ...       ...   ...
# 1512  10.0          1.39     190846.01  57529.11   56366.66  17531.78     0
# 1513  11.0          1.51     178235.75  43325.87   52189.61  19419.57     0
# 1514  12.0          1.48     178410.82  46364.75   52893.38  16736.92     0
# 1515  13.0          1.47     189131.52  54110.79   53593.58  17495.42     0
# 1516  14.0          1.43     182978.30  43116.41   54193.42  16563.91     0
#
#         year  region  Month  Day
# ...

# %% [markdown]
# Here, The range of the columns are not highly dirrenet. We also didn't use PCA. So, there is no need to use Scaling.

# %% [markdown]
# # Model Creating

# %% [markdown]
# # Best random state

# %% [markdown]
# # RandomForest Regression

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_t=sc.fit_transform(x)
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
from sklearn.metrics import r2_score

# %%
max_scr=0
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x_t,y,test_size=.20,random_state=i)
    rf.fit(x_train,y_train)
    pred_train=rf.predict(x_train)
    pred_test=rf.predict(x_test)
    if round(r2_score(y_train,pred_train)*100,2)==round(r2_score(y_test,pred_test)*100,2):
        print("At random state",i,"The model performs very well")
        print("At random state :-",i)
        print("Training r2_score is :-",r2_score(y_train,pred_train)*100)
        print("Testing r2_score is :-",r2_score(y_test,pred_test)*100)
        
print("At random state",i,"The model performs very well")
print("At random state :-",i)
print("Training r2_score is :-",r2_score(y_train,pred_train)*100)
print("Testing r2_score is :-",r2_score(y_test,pred_test)*100)
# Out:
# At random state 999 The model performs very well
# At random state :- 999
# Training r2_score is :- 97.0828338320805
# Testing r2_score is :- 79.82068392962009

# %%
x_train,x_test,y_train,y_test=train_test_split(x_t,y,test_size=.20,random_state=999)

# %%
def plots(avocado, var, t):
    plt.figure(figsize=(13,5))
    plt.subplot(121)
    sns.kdeplot(avocado[var])
    plt.title('before ' + str(t).split('(')[0])
    
    plt.subplot(122)
    p1 = t.fit_transform(avocado[[var]]).flatten()
    sns.kdeplot(p1)
    plt.title('after ' + str(t).split('(')[0])

# %% [markdown]
# Here, I have used the random state 999 what we have got in the previous stage.

# %% [markdown]
# # Use GridSearchCV and Find out best CV

# %% [markdown]
# # RandomForest

# %% [markdown]
# # from sklearn.model_selection import GridSearchCV
# from sklearn.model_selection import cross_val_score
# import warnings
# warnings.filterwarnings('ignore')

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
parameters={'criterion':['mse','friedman_mse','mae'],'n_estimators':[100,200,300]}  
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'friedman_mse', 'n_estimators': 200}

# %%
from sklearn.model_selection import cross_val_score
rf=RandomForestRegressor(n_estimators=100, criterion='mse', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='auto', max_leaf_nodes=None, min_impurity_decrease=0.0, min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=None, random_state=None, verbose=0, warm_start=False, ccp_alpha=0.0, max_samples=None)
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_rf=rf.predict(x_test)

rfs=r2_score(y_test,pred_rf)
print('R2 Score:',rfs*100)

rfscore=cross_val_score(rf,x_t,y,cv=3)
rfc=rfscore.mean()
print('Cross Val Score : ',rfc*100)
# Out:
# R2 Score: 80.34360798651076
# Cross Val Score :  -3.7187800896037237

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
print("Error")
print("Mean Absolute Eror : ",mean_absolute_error(y_test,pred_rf))
print("Mean Squared Eror : ",mean_squared_error(y_test,pred_rf))
print("Root Mean Squared Eror : ",np.sqrt(mean_squared_error(y_test,pred_rf)))
# Out:
# Error
# Mean Absolute Eror :  0.0606674342105263
# Mean Squared Eror :  0.007034816940789478
# Root Mean Squared Eror :  0.08387381558501722

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_rf,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel("Actual compressive strength",fontsize=14)
plt.ylabel("Predicted compressive strength",fontsize=14)
plt.title('Random Forest Regression',fontsize=18)
plt.show()

# %% [markdown]
# Here, the points are little bit closer to the line

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.linear_model import Ridge

parameters={'alpha':[.0001,.001,.01,.1,1,10],'copy_X':[True,False],'random_state':list(range(0,10)),'fit_intercept':[True,False],'normalize':[True,False],'tol':[.0001,.001,.01,.1,1,10]}
rd=Ridge()
clf=GridSearchCV(rd,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.01, 'copy_X': True, 'fit_intercept': True, 'normalize': True, 'random_state': 0, 'tol': 0.0001}

# %%
rd=Ridge(alpha=0.01, copy_X= True, fit_intercept= True, normalize= True, random_state= 0, tol= 0.0001)
rd.fit(x_train,y_train)
rd.score(x_train,y_train)
pred_rd=rd.predict(x_test)

rds=r2_score(y_test,pred_rd)
print('R2 Score:',rds*100)

rdscore=cross_val_score(rd,x_t,y,cv=3)
rdc=rdscore.mean()
print('Cross Val Score : ',rdc*100)
# Out:
# R2 Score: 29.230178123618657
# Cross Val Score :  14.2402204699555

# %%
print("Error")
print("Mean Absolute Eror : ",mean_absolute_error(y_test,pred_rd))
print("Mean Squared Eror : ",mean_squared_error(y_test,pred_rd))
print("Root Mean Squared Eror : ",np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# Error
# Mean Absolute Eror :  0.12376537119221148
# Mean Squared Eror :  0.02532777843924608
# Root Mean Squared Eror :  0.15914703402591604

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_rd,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel("Actual compressive strength",fontsize=14)
plt.ylabel("Predicted compressive strength",fontsize=14)
plt.title('Ridge Regression',fontsize=18)
plt.show()

# %% [markdown]
# In the middle the points are closer to the line. But the other points are far.

# %% [markdown]
# # Ensemble Techniques :

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

parameters={'criterion':['mse','friedman_mse','mae'],'splitter':['best','random']}
dt=DecisionTreeRegressor()
clf=GridSearchCV(dt,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'friedman_mse', 'splitter': 'random'}

# %%
dt=DecisionTreeRegressor(criterion='friedman_mse', splitter='random', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=None, random_state=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_impurity_split=None, ccp_alpha=0.0)
dt.fit(x_train,y_train)
dt.score(x_train,y_train)
pred_dt=dt.predict(x_test)

dts=r2_score(y_test,pred_dt)
print('R2 Score:',dts*100)

dtscore=cross_val_score(dt,x_t,y,cv=3)
dtc=dtscore.mean()
print('Cross Val Score : ',dtc*100)
# Out:
# R2 Score: 73.21100747673775
# Cross Val Score :  -74.0847327818468

# %%
print("Error")
print("Mean Absolute Eror : ",mean_absolute_error(y_test,pred_dt))
print("Mean Squared Eror : ",mean_squared_error(y_test,pred_dt))
print("Root Mean Squared Eror : ",np.sqrt(mean_squared_error(y_test,pred_dt)))
# Out:
# Error
# Mean Absolute Eror :  0.06763157894736843
# Mean Squared Eror :  0.0095875
# Root Mean Squared Eror :  0.0979157801378307

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_dt,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel("Actual compressive strength",fontsize=14)
plt.ylabel("Predicted compressive strength",fontsize=14)
plt.title('Decision Tree Regression',fontsize=18)
plt.show()

# %% [markdown]
# # Gradient Boosting Regressor

# %%
from sklearn.datasets import make_regression
from sklearn.ensemble import GradientBoostingRegressor

parameters={'n_estimators':[50,100,200],'criterion':['friedman_mse', 'mse', 'mae']}  #Search in google for more parameter
gbr=GradientBoostingRegressor()
clf=GridSearchCV(gbr,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'n_estimators': 200}

# %%
gbr=GradientBoostingRegressor(loss='ls', learning_rate=0.1, n_estimators=200, subsample=1.0, criterion='mse', min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_depth=3, min_impurity_decrease=0.0, min_impurity_split=None, init=None, random_state=None, max_features=None, alpha=0.9, verbose=0, max_leaf_nodes=None, warm_start=False, validation_fraction=0.1, n_iter_no_change=None, tol=0.0001, ccp_alpha=0.0)
gbr.fit(x_train,y_train)
gbr.score(x_train,y_train)
pred_gbr=gbr.predict(x_test)

gbrs=r2_score(y_test,pred_gbr)
print('R2 Score:',gbrs*100)

gbrscore=cross_val_score(gbr,x_t,y,cv=3)
gbrc=gbrscore.mean()
print('Cross Val Score : ',gbrc*100)
# Out:
# R2 Score: 76.37872938312914
# Cross Val Score :  -2.7010627879831257

# %%
print("Error")
print("Mean Absolute Eror : ",mean_absolute_error(y_test,pred_gbr))
print("Mean Squared Eror : ",mean_squared_error(y_test,pred_gbr))
print("Root Mean Squared Eror : ",np.sqrt(mean_squared_error(y_test,pred_gbr)))
# Out:
# Error
# Mean Absolute Eror :  0.07065288541243697
# Mean Squared Eror :  0.008453805489049086
# Root Mean Squared Eror :  0.09194457835592638

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_gbr,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel("Actual compressive strength",fontsize=14)
plt.ylabel("Predicted compressive strength",fontsize=14)
plt.title('Gradient Boosting Regressor',fontsize=18)
plt.show()

# %% [markdown]
# # SVR

# %%
from sklearn.svm import SVR

parameters={'kernel':['linear', 'poly', 'rbf', 'sigmoid'],'gamma':['scale','auto']}  #'gamma':['scale','auto']
sv=SVR()
clf=GridSearchCV(sv,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'gamma': 'scale', 'kernel': 'rbf'}

# %%
sv=SVR(kernel='rbf', degree=3, gamma='scale', coef0=0.0, tol=0.001, C=1.0, epsilon=0.1, shrinking=True, cache_size=200, verbose=False, max_iter=- 1)
sv.fit(x_train,y_train)
sv.score(x_train,y_train)
pred_sv=sv.predict(x_test)

svs=r2_score(y_test,pred_sv)
print('R2 Score:',svs*100)

svscore=cross_val_score(sv,x_t,y,cv=3)
svc=svscore.mean()
print('Cross Val Score : ',svc*100)
# Out:
# R2 Score: 63.41314699509424
# Cross Val Score :  -19.146808176573295

# %%
print("Error")
print("Mean Absolute Eror : ",mean_absolute_error(y_test,pred_sv))
print("Mean Squared Eror : ",mean_squared_error(y_test,pred_sv))
print("Root Mean Squared Eror : ",np.sqrt(mean_squared_error(y_test,pred_sv)))
# Out:
# Error
# Mean Absolute Eror :  0.08737168559796755
# Mean Squared Eror :  0.013094051703509824
# Root Mean Squared Eror :  0.11442924321828675

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_sv,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel("Actual compressive strength",fontsize=14)
plt.ylabel("Predicted compressive strength",fontsize=14)
plt.title('SVR',fontsize=18)
plt.show()

# %% [markdown]
# # Lasso:

# %%
from sklearn.linear_model import Lasso

parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.001, 'random_state': 0}

# %%
ls=Lasso(alpha=0.001,fit_intercept=True, normalize=False, precompute=False, copy_X=True, max_iter=1000, tol=0.0001, warm_start=False, positive=False, random_state=0, selection='cyclic')
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)

lss=r2_score(y_test,pred_ls)
print('R2 Score:',svs*100)

lsscore=cross_val_score(ls,x_t,y,cv=3)
lsc=lsscore.mean()
print('Cross Val Score : ',svc*100)
# Out:
# R2 Score: 63.41314699509424
# Cross Val Score :  -19.146808176573295

# %%
print("Error")
print("Mean Absolute Eror : ",mean_absolute_error(y_test,pred_ls))
print("Mean Squared Eror : ",mean_squared_error(y_test,pred_ls))
print("Root Mean Squared Eror : ",np.sqrt(mean_squared_error(y_test,pred_ls)))
# Out:
# Error
# Mean Absolute Eror :  0.12431372347160126
# Mean Squared Eror :  0.025536549255349667
# Root Mean Squared Eror :  0.159801593406792

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_ls,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel("Actual compressive strength",fontsize=14)
plt.ylabel("Predicted compressive strength",fontsize=14)
plt.title('Lasso Regression',fontsize=18)
plt.show()

# %% [markdown]
# # Linear Regression:

# %%
from sklearn.linear_model import LinearRegression
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.001, 'random_state': 0}

# %%
#fit_intercept=True, normalize=False, copy_X=True, n_jobs=None, positive=False
lr=LinearRegression(fit_intercept=True, normalize=False, copy_X=True, n_jobs=None)
lr.fit(x_train,y_train)
lr.score(x_train,y_train)
pred_lr=lr.predict(x_test)

lrr=r2_score(y_test,pred_lr)
print('R2 Score:',svs*100)

lrscore=cross_val_score(lr,x_t,y,cv=3)
lrc=lrscore.mean()
print('Cross Val Score : ',svc*100)
# Out:
# R2 Score: 63.41314699509424
# Cross Val Score :  -19.146808176573295

# %%
print("Error")
print("Mean Absolute Eror : ",mean_absolute_error(y_test,pred_lr))
print("Mean Squared Eror : ",mean_squared_error(y_test,pred_lr))
print("Root Mean Squared Eror : ",np.sqrt(mean_squared_error(y_test,pred_lr)))
# Out:
# Error
# Mean Absolute Eror :  0.12383495918505565
# Mean Squared Eror :  0.025330334572885197
# Root Mean Squared Eror :  0.159155064553049

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_lr,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel("Actual compressive strength",fontsize=14)
plt.ylabel("Predicted compressive strength",fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.show()

# %% [markdown]
# # KNeighbour

# %%
from sklearn.neighbors import KNeighborsRegressor
parameters={'weights':['uniform','distance'],'algorithm':['auto', 'ball_tree', 'kd_tree', 'brute'],}
neigh=KNeighborsRegressor()
clf=GridSearchCV(neigh,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)

#n_neighbors=5, *, weights='uniform', algorithm='auto', leaf_size=30, p=2, metric='minkowski', metric_params=None, n_jobs=None, **kwargs
# Out:
# {'algorithm': 'auto', 'weights': 'distance'}

# %%
neigh=KNeighborsRegressor(n_neighbors=5,weights='distance', algorithm='auto', leaf_size=30, p=2, metric='minkowski', metric_params=None, n_jobs=None)
neigh.fit(x_train,y_train)
neigh.score(x_train,y_train)
pred_neigh=neigh.predict(x_test)

neighs=r2_score(y_test,pred_neigh)
print('R2 Score:',svs*100)

neighscore=cross_val_score(neigh,x_t,y,cv=3)
neighc=neighscore.mean()
print('Cross Val Score : ',svc*100)
# Out:
# R2 Score: 63.41314699509424
# Cross Val Score :  -19.146808176573295

# %%
print("Error")
print("Mean Absolute Eror : ",mean_absolute_error(y_test,pred_neigh))
print("Mean Squared Eror : ",mean_squared_error(y_test,pred_neigh))
print("Root Mean Squared Eror : ",np.sqrt(mean_squared_error(y_test,pred_neigh)))
# Out:
# Error
# Mean Absolute Eror :  0.088000957497624
# Mean Squared Eror :  0.013180421114641887
# Root Mean Squared Eror :  0.11480601515008648

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_neigh,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel("Actual compressive strength",fontsize=14)
plt.ylabel("Predicted compressive strength",fontsize=14)
plt.title('KNeighbors Regression',fontsize=18)
plt.show()

# %% [markdown]
# From above we can find the best r2 score from Random Forest.
#
# R2 Score: 81.25134784183653
#
# Cross Val Score :  22.143597562006967
#
# Now, we will use this algorithm to predict.

# %% [markdown]
# # Saving the model

# %%
import pickle
filename='Avocoda.pkl'
pickle.dump(rf,open(filename,'wb'))

# %%
import pickle

# %%
with open('Avocoda.pkl','rb') as f:
    x=pickle.load(f)

# %% [markdown]
# # Conclusion:

# %%
import numpy as np
a=np.array(y_test)
a
# Out:
# array([1.1 , 1.22, 1.03, 1.19, 1.09, 1.07, 1.16, 1.07, 1.03, 1.02, 0.92,
#        0.95, 0.94, 0.82, 1.25, 0.99, 1.01, 1.14, 1.31, 1.22, 1.18, 1.13,
#        1.04, 1.17, 1.21, 1.04, 1.07, 0.87, 0.97, 1.06, 1.03, 1.08, 1.18,
#        1.15, 1.04, 0.96, 1.21, 0.58, 0.94, 1.08, 1.08, 0.8 , 1.22, 0.62,
#        0.91, 1.11, 1.29, 1.17, 0.74, 0.71, 1.32, 1.21, 1.22, 1.03, 0.63,
#        1.2 , 1.16, 1.26, 0.84, 1.22, 1.1 , 1.09, 0.99, 1.18, 0.93, 0.7 ,
#        1.24, 0.82, 0.9 , 1.26, 1.  , 1.26, 1.03, 1.62, 1.53, 0.94, 1.19,
#        0.96, 1.61, 1.  , 1.08, 1.11, 1.02, 1.11, 0.89, 1.08, 1.05, 1.14,
#        1.06, 1.05, 0.97, 0.77, 1.12, 0.99, 1.23, 1.32, 1.17, 1.43, 1.03,
#        1.09, 0.56, 1.11, 1.1 , 1.03, 0.76, 1.15, 0.94, 1.09, 1.16, 1.3 ,
#        1.03, 1.02, 1.23, 1.2 , 1.11, 0.96, 1.11, 1.1 , 1.03, 0.99, 1.25,
#        0.79, 1.15, 1.36, 1.16, 1.26, 1.01, 1.07, 1.04, 1.16, 1.02, 1.26,
#        1.09, 1.32, 1.09, 0.87, 1.04, 1.05, 1.06, 1.01, 1.22, 1.07, 1.19,
# ...

# %%
predicted=np.array(rf.predict(x_test))
predicted
# Out:
# array([1.0932, 1.2122, 1.0752, 1.1345, 1.089 , 1.1356, 1.198 , 1.0364,
#        1.0237, 1.0629, 1.103 , 1.0066, 1.0201, 1.043 , 1.1412, 0.9817,
#        1.0509, 1.2453, 1.1973, 1.0518, 1.0992, 1.088 , 1.0767, 1.192 ,
#        1.1954, 1.0261, 1.1363, 0.8492, 1.0022, 1.188 , 1.1264, 1.0462,
#        1.1178, 1.0992, 1.1996, 0.9498, 1.069 , 0.5734, 1.0119, 1.259 ,
#        1.1813, 0.8143, 1.1383, 0.6936, 1.0167, 1.0925, 1.2435, 1.1452,
#        0.7557, 0.7577, 1.2302, 1.1342, 1.1833, 1.0486, 0.6117, 1.1442,
#        1.2023, 1.1832, 0.9175, 1.1808, 1.0171, 1.123 , 1.0157, 1.3058,
#        0.9094, 0.6596, 1.1689, 0.7912, 0.7884, 1.1924, 1.0447, 1.1378,
#        1.0725, 1.2989, 1.3373, 0.9302, 1.217 , 1.1236, 1.4331, 1.0737,
#        1.1012, 1.038 , 1.0158, 1.0344, 0.9459, 1.0618, 0.9688, 1.1996,
#        1.0374, 1.0781, 1.0124, 0.7699, 1.123 , 0.9972, 1.2245, 1.2979,
#        1.2078, 1.2413, 1.1286, 1.0961, 0.5682, 1.1757, 1.068 , 1.0368,
# ...

# %%
df_com=pd.DataFrame({"original":a,"predicted":predicted},index=range(len(a)))
df_com
# Out:
#      original  predicted
# 0        1.10     1.0932
# 1        1.22     1.2122
# 2        1.03     1.0752
# 3        1.19     1.1345
# 4        1.09     1.0890
# ..        ...        ...
# 299      1.05     1.1109
# 300      0.89     1.0772
# 301      0.68     0.7094
# 302      0.99     1.0175
# 303      0.92     0.9402
#
# [304 rows x 2 columns]

# %% [markdown]
# Here we can see that the predicted value is very close to predicted value. The predicted value is 81%accurate
